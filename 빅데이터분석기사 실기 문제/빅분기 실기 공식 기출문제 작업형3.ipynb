# %% [markdown]
# # 빅데이터분석기사 실기 공식 기출문제 작업형3 문제유형

# %% [markdown]
# ![스크린샷 2023-05-04 오후 2.08.30.png](data:image/png;base64,...)

# %% [markdown]
# * 데이터셋 : data/blood_pressure.csv

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/drive/MyDrive/빅분기 실기 연습문제/blood_pressure.csv')

df.head()
# Out:
#    patient   sex agegrp  bp_before  bp_after
# 0        1  Male  30-45        143       153
# 1        2  Male  30-45        163       170
# 2        3  Male  30-45        153       168
# 3        4  Male  30-45        153       142
# 4        5  Male  30-45        146       141

# %%
#문제(a) 풀이

df['diff'] = df['bp_after'] - df['bp_before']

answer_a = np.round(df['diff'].mean(),2)

print(answer_a)
# Out:
# -5.09

# %% [markdown]
# 해당 문제에서
# 귀무가설 : 해당 치료가 효과가 없다.
# 대립가설 : 해당 치료가 효과가 있다.
#
# 쌍체표본 t검정에서 p-value가 유의수준보다 작으면 귀무가설을 기각하고 대립가설을 채택하며, 유의수준보다 크다면 그와 반대로 귀무가설을 채택한다.

# %%
#문제(b) 풀이
from scipy import stats

# 대립가설 기준으로 하여, 첫번째 column 값이 두번째 컬럼 값보다 더 커야한다면 alternative = greater, 작아야 한다면 alternative = less 로 설정
ttest_result = stats.ttest_rel(df['bp_after'], df['bp_before'], alternative='less')
print(ttest_result)

answer_b = np.round(ttest_result[0],2)

print(answer_b)
# Out:
# TtestResult(statistic=-3.3371870510833657, pvalue=0.0005648957322420411, df=119)
# -3.34

# %%
#문제(c) 풀이

p_value = np.round(ttest_result[1],4)
print(p_value)

print('p_value 값이',p_value,'이고 이는 유의수준 0.05보다 작으므로 귀무가설을 기각하고 대립가설을 채택한다. 즉 고혈압 치료가 효과가 있음.')
# Out:
# 0.0006
# p_value 값이 0.0006 이고 이는 유의수준 0.05보다 작으므로 귀무가설을 기각하고 대립가설을 채택한다. 즉 고혈압 치료가 효과가 있음.
