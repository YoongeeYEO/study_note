# %% [markdown]
# # 007. Products of Array Discluding Self
#
# [문제 007](https://neetcode.io/problems/products-of-array-discluding-self)
#
# - Given an integer array nums, return an array output where output[i] is the product of all the elements of nums except nums[i].
#
# - Each product is guaranteed to fit in a 32-bit integer.
#
# - Follow-up: Could you solve it in O(n) time without using the division operation?
#
# Constraints:
# - 2 <= nums.length <= 1000
# - -20 <= nums[i] <= 20

# %% [markdown]
# ## Solutions
# - O(n)의 방법으로 풀어야 하기 때문에, DP의 방법인 누적 배열을 만들어서 해결한다.
# - 누적 곱셈을 이용하여 자신을 제외한 왼쪽 곱 배열과 오른쪽 곱 배열을 저장해두고 서로 곱하면 된다.

# %%
from typing import List

class Solution:
    def productExceptSelf(self, nums: List[int]) -> List[int]:
        answer = []
        product = 1

        for i in range(len(nums)):
            answer.append(product)
            product *= nums[i]

        product = 1
        for i in range(len(nums)-1, -1, -1):
            answer[i] *= product
            product *= nums[i]

        return answer

# %%
# Example

nums = [1,2,4,6]

solution = Solution()
solution.productExceptSelf(nums)
# Out:
# [48, 24, 12, 8]

# %%
# Example2

nums2 = [-1,0,1,2,3]

solution2 = Solution()
solution2.productExceptSelf(nums2)
# Out:
# [0, -6, 0, 0, 0]
