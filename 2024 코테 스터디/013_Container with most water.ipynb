# %% [markdown]
# # 013. Container with most water
#
# [문제 013](https://neetcode.io/problems/max-water-container)
#
# - You are given an integer array heights where heights[i] represents the height of the
# i
# t
# h
# i
# th
#   bar.
#
# - You may choose any two bars to form a container. Return the maximum amount of water a container can store.
#
# ![public.avif](data:image/avif;base64,...)
#
# Constraints:
# - 2 <= height.length <= 1000
# - 0 <= height[i] <= 1000

# %% [markdown]
# ## Solutions
# - heights 리스트의 모든 원소에 대해 순차적으로 두개식 비교해보며 area 값을 구한다.
# - area 값 중 가장 큰 값을 max area 로 return!

# %%
from typing import List

class Solution:
    def maxArea(self, heights: List[int]) -> int:
        max_area = 0
        for i in range(len(heights)):
            for j in range(i+1, len(heights)):
                area = min(heights[i], heights[j]) * (j-i)
                max_area = max(max_area, area)
        return max_area

# %%
# Example
heights = [1,7,2,5,4,7,3,6]

s = Solution()
s.maxArea(heights)
# Out:
# 36

# %%
# Example2
heights = [2,2,2]

s.maxArea(heights)
# Out:
# 4
