# %% [markdown]
# # 003. Two Integer Sum
#
# [문제 003](https://neetcode.io/problems/two-integer-sum)
#
# - Given an array of integers nums and an integer target, return the indices i and j such that nums[i] + nums[j] == target and i != j.
#
# - You may assume that every input has exactly one pair of indices i and j that satisfy the condition.
#
# - Return the answer with the smaller index first.
#
# Constraints
#
# - 2 <= nums.length <= 1000
# - -10,000,000 <= nums[i] <= 10,000,000
# - -10,000,000 <= target <= 10,000,000

# %% [markdown]
# ## Solutions
#
# - 이중 반복문을 활용
#
# - nums 리스트 내 모든 요소들을 추출하고 각각을 합한 결과가 target값일때 nums 리스트의 해당 인덱스값을 반환

# %%
from typing import List

class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        for i in range(len(nums)):
            for j in range(i+1, len(nums)):
                if nums[i]+nums[j] == target:
                    return [i,j]

# %%
# Example

nums = [4,5,6]
target = 10

solution = Solution()
solution.twoSum(nums, target)

solution.twoSum(nums, target)
# Out:
# [0, 2]

# %%
# Example2

nums2 = [1,6,7]
target2 = 90

solution = Solution()
solution.twoSum(nums2, target2)

# %% [markdown]
# target값이 리스트 내 두개의 값을 더한결과가 아닐땐 아무것도 반환하지 않음.

# %%
# Example3
nums3 = [5,5]
target3 = 10

solution = Solution()
solution.twoSum(nums3, target3)
# Out:
# [0, 1]
