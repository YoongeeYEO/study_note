# %% [markdown]
# # Pre-trained Text-to-Music Generation 모델 사용법

# %%
# !git clone https://github.com/sander-wood/text-to-music.git

# %% [markdown]
# * git clone 통해서 깃허브에 공유된 모델 인퍼런스 코드를 가져온다
# * 가져온 모델은 노션에 적어놓은대로, 약 28만쌍의 English text-music pairs로 사전 학습된 BART 기반의 Text-to-Music Generation ModelAutoModel for Seq2SeqLM 이다.
#
# [AutoModel for Seq2SeqLM]
# - Hugging Face Transformers 라이브러리에서 제공하는 자연어처리(NLP)를 위한 모델 클래스 중 하나로, 이 클래스는 Encoder-Decoder 구조의 Sequence-to-Sequence (Seq2Seq) 모델을 자동으로 생성해줌
# - 모델의 아키텍처와 하이퍼파라미터를 자동으로 선택하여 생성하며, 다양한 사전 학습된 모델 (예: BART, T5, Marian, etc.)에 대한 Wrapper 역할을 수행. 이를 통해, Seq2Seq 모델을 생성하는 데 필요한 복잡한 작업을 최소화하고 간단한 코드로 모델 생성 가능
# - 해당 Text to music generation 모델은 282,870개의 영어 텍스트-음악 쌍에서 BART 모델 기반을 기반으로 미세 조정을 수행하며, output은 ABC 표기법(음악)으로 출력됨.
# - 출력된 output을 아래 웹사이트에 그대로 넣으면, 모델이 생성한 노래를 들을 수 있음...

# %%
# !pip install unidecode
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 KB 13.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# * git clone 에서 가져온 파일 중, input_text.txt 라는 파일에 생성하고자 하는 음악 스타일을 영어문장 형태로 작성 후 저장한다.
#
# * input text : This is a classical piece for a solo violin music that showcases the instrument's range and technical abilities.

# %% [markdown]
# * run_inference.py 파일 실행할 때, num_tunes = 3 으로 설정하면 더욱 다양한 조합으로 된 음악을 생성할 수 있음.

# %%
# !pip install samplings
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 84.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 26.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 102.8 MB/s eta 0:00:00
# ...

# %%
# !python /content/drive/MyDrive/앱개발/text-to-music/run_inference.py -num_tunes 3 -max_length 1024 -top_p 0.9 -temperature 1.0 -seed 0
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA A100-SXM4-40GB
#
# ##################### HYPERPARAMETERS ######################
#
# num_tunes: 3
# max_length: 1024
# top_p: 0.9
# temperature: 1.0
# seed: 0
#
# ######################## INPUT TEXT ########################
#
# This is a classical piece for a solo violin music that showcases the instrument's range and technical abilities.
#
# ...
# ####################### OUTPUT TUNES #######################
#
# X:1
# 2023-03-27 14:28:24.705060: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %% [markdown]
# * 2번째 text : Craft a cinematic orchestral piece with sweeping strings and brass, that builds to a climactic finale.

# %%
# !python /content/drive/MyDrive/앱개발/text-to-music/run_inference.py -num_tunes 3 -max_length 1024 -top_p 0.9 -temperature 1.0 -seed 0
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA A100-SXM4-40GB
#
# ##################### HYPERPARAMETERS ######################
#
# num_tunes: 3
# max_length: 1024
# top_p: 0.9
# temperature: 1.0
# seed: 0
#
# ######################## INPUT TEXT ########################
#
# Craft a cinematic orchestral piece with sweeping strings and brass, that builds to a climactic finale.
#
# ####################### OUTPUT TUNES #######################
#
# X:1
# 2023-03-27 14:34:27.230902: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...
